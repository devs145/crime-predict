# %% [markdown]
# **CPSC 4660 Project Notebook**

# %% [markdown]
# Import all needed libraries.

# %%
import numpy as np
import pandas as pd
import math
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Print the initial, unmodified table from the csv.

# %%
crimes = pd.read_csv('crime.csv')
print("Crime in Vancouver (2003-2017)")
display(crimes)
# Out:
# Crime in Vancouver (2003-2017)
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                                             Other Theft  2003      5   12
# 1                                             Other Theft  2003      5    7
# 2                                             Other Theft  2003      4   23
# 3                                             Other Theft  2003      4   20
# 4                                             Other Theft  2003      4   12
# ...                                                   ...   ...    ...  ...
# 530647                  Break and Enter Residential/Other  2017      3    3
# 530648                                           Mischief  2017      5   29
# 530649                           Offence Against a Person  2017      4   13
# 530650                                 Theft from Vehicle  2017      6    5
# 530651  Vehicle Collision or Pedestrian Struck (with I...  2017      6    6
#
#         HOUR  MINUTE              HUNDRED_BLOCK              NEIGHBOURHOOD  \
# 0       16.0    15.0           9XX TERMINAL AVE                 Strathcona
# 1       15.0    20.0           9XX TERMINAL AVE                 Strathcona
# 2       16.0    40.0           9XX TERMINAL AVE                 Strathcona
# 3       11.0    15.0           9XX TERMINAL AVE                 Strathcona
# 4       17.0    45.0           9XX TERMINAL AVE                 Strathcona
# ...      ...     ...                        ...                        ...
# 530647   9.0    16.0             31XX ADANAC ST           Hastings-Sunrise
# 530648  22.0    30.0             14XX E 7TH AVE         Grandview-Woodland
# 530649   NaN     NaN  OFFSET TO PROTECT PRIVACY                        NaN
# 530650  17.0     0.0            8XX HAMILTON ST  Central Business District
# 530651  17.0    38.0         13XX BLOCK PARK DR                    Marpole
#
#                 X           Y   Latitude   Longitude
# 0       493906.50  5457452.47  49.269802 -123.083763
# 1       493906.50  5457452.47  49.269802 -123.083763
# 2       493906.50  5457452.47  49.269802 -123.083763
# 3       493906.50  5457452.47  49.269802 -123.083763
# 4       493906.50  5457452.47  49.269802 -123.083763
# ...           ...         ...        ...         ...
# 530647  497265.49  5458296.71  49.277420 -123.037595
# 530648  494533.97  5456824.97  49.264163 -123.075129
# 530649       0.00        0.00   0.000000    0.000000
# 530650  491487.85  5458385.78  49.278168 -123.117031
# 530651  490204.00  5451444.00  49.215706 -123.134512
#
# [530652 rows x 12 columns]

# %% [markdown]
# In this dataset, the crime 'Offence Against a Person' has all data missing except year, month, and day any time it appears. This has been done to protect the privacy of those whom the offence was commited against. Unfortunately, this means that information provided from records of this type of crime will not be useful in providing predictive information. So, despite the fact that records containing 'Offence Against a Person' make up 10.2% of the crime in this dataset (54,142 out of 530,652 rows), this crime will have to be removed from the dataset.

# %%
crimes = crimes[crimes.TYPE != 'Offence Against a Person']
display(crimes)
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                                             Other Theft  2003      5   12
# 1                                             Other Theft  2003      5    7
# 2                                             Other Theft  2003      4   23
# 3                                             Other Theft  2003      4   20
# 4                                             Other Theft  2003      4   12
# ...                                                   ...   ...    ...  ...
# 530646                                           Mischief  2017      1   18
# 530647                  Break and Enter Residential/Other  2017      3    3
# 530648                                           Mischief  2017      5   29
# 530650                                 Theft from Vehicle  2017      6    5
# 530651  Vehicle Collision or Pedestrian Struck (with I...  2017      6    6
#
#         HOUR  MINUTE       HUNDRED_BLOCK              NEIGHBOURHOOD  \
# 0       16.0    15.0    9XX TERMINAL AVE                 Strathcona
# 1       15.0    20.0    9XX TERMINAL AVE                 Strathcona
# 2       16.0    40.0    9XX TERMINAL AVE                 Strathcona
# 3       11.0    15.0    9XX TERMINAL AVE                 Strathcona
# 4       17.0    45.0    9XX TERMINAL AVE                 Strathcona
# ...      ...     ...                 ...                        ...
# 530646  14.0    44.0  14XX E HASTINGS ST         Grandview-Woodland
# 530647   9.0    16.0      31XX ADANAC ST           Hastings-Sunrise
# 530648  22.0    30.0      14XX E 7TH AVE         Grandview-Woodland
# 530650  17.0     0.0     8XX HAMILTON ST  Central Business District
# 530651  17.0    38.0  13XX BLOCK PARK DR                    Marpole
#
#                 X           Y   Latitude   Longitude
# 0       493906.50  5457452.47  49.269802 -123.083763
# 1       493906.50  5457452.47  49.269802 -123.083763
# 2       493906.50  5457452.47  49.269802 -123.083763
# 3       493906.50  5457452.47  49.269802 -123.083763
# 4       493906.50  5457452.47  49.269802 -123.083763
# ...           ...         ...        ...         ...
# 530646  494563.75  5458727.40  49.281276 -123.074746
# 530647  497265.49  5458296.71  49.277420 -123.037595
# 530648  494533.97  5456824.97  49.264163 -123.075129
# 530650  491487.85  5458385.78  49.278168 -123.117031
# 530651  490204.00  5451444.00  49.215706 -123.134512
#
# [476510 rows x 12 columns]

# %% [markdown]
# The dataset being worked with should be as complete as possible. So, as a precaution, any potential records containing null/NA/NaN values that may remain in the dataset need to be removed.

# %%
crimes.dropna(inplace=True)
display(crimes)
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                                             Other Theft  2003      5   12
# 1                                             Other Theft  2003      5    7
# 2                                             Other Theft  2003      4   23
# 3                                             Other Theft  2003      4   20
# 4                                             Other Theft  2003      4   12
# ...                                                   ...   ...    ...  ...
# 530646                                           Mischief  2017      1   18
# 530647                  Break and Enter Residential/Other  2017      3    3
# 530648                                           Mischief  2017      5   29
# 530650                                 Theft from Vehicle  2017      6    5
# 530651  Vehicle Collision or Pedestrian Struck (with I...  2017      6    6
#
#         HOUR  MINUTE       HUNDRED_BLOCK              NEIGHBOURHOOD  \
# 0       16.0    15.0    9XX TERMINAL AVE                 Strathcona
# 1       15.0    20.0    9XX TERMINAL AVE                 Strathcona
# 2       16.0    40.0    9XX TERMINAL AVE                 Strathcona
# 3       11.0    15.0    9XX TERMINAL AVE                 Strathcona
# 4       17.0    45.0    9XX TERMINAL AVE                 Strathcona
# ...      ...     ...                 ...                        ...
# 530646  14.0    44.0  14XX E HASTINGS ST         Grandview-Woodland
# 530647   9.0    16.0      31XX ADANAC ST           Hastings-Sunrise
# 530648  22.0    30.0      14XX E 7TH AVE         Grandview-Woodland
# 530650  17.0     0.0     8XX HAMILTON ST  Central Business District
# 530651  17.0    38.0  13XX BLOCK PARK DR                    Marpole
#
#                 X           Y   Latitude   Longitude
# 0       493906.50  5457452.47  49.269802 -123.083763
# 1       493906.50  5457452.47  49.269802 -123.083763
# 2       493906.50  5457452.47  49.269802 -123.083763
# 3       493906.50  5457452.47  49.269802 -123.083763
# 4       493906.50  5457452.47  49.269802 -123.083763
# ...           ...         ...        ...         ...
# 530646  494563.75  5458727.40  49.281276 -123.074746
# 530647  497265.49  5458296.71  49.277420 -123.037595
# 530648  494533.97  5456824.97  49.264163 -123.075129
# 530650  491487.85  5458385.78  49.278168 -123.117031
# 530651  490204.00  5451444.00  49.215706 -123.134512
#
# [474015 rows x 12 columns]

# %% [markdown]
# Now the number of times each crime type appears in the dataset needs to be determined. This information will be used to reduce the number of crimes being used in the model so that it can be more focused on the crime that occurs most frequently.

# %%
crime_type_counts = crimes.TYPE.value_counts()
print(crime_type_counts)
crimes_size = len(crimes.index)
crime_types = crime_type_counts.index
crime_counts = crime_type_counts.values
crime_percentages = (crime_counts / crimes_size) * 100
crime_percentages_len = len(crime_percentages)
for i in range(crime_percentages_len):
    crime_percentages[i] = round(crime_percentages[i], 2)
for i in range(crime_percentages_len):
    print(f'{crime_types[i]:<55}', f'{"{0:.2f}".format(crime_percentages[i]):>6}', '%')
# Out:
# Theft from Vehicle                                        170889
# Mischief                                                   70157
# Break and Enter Residential/Other                          60856
# Other Theft                                                52160
# Theft of Vehicle                                           38351
# Break and Enter Commercial                                 33841
# Theft of Bicycle                                           25620
# Vehicle Collision or Pedestrian Struck (with Injury)       21887
# Vehicle Collision or Pedestrian Struck (with Fatality)       254
# Name: TYPE, dtype: int64
# Theft from Vehicle                                       36.05 %
# Mischief                                                 14.80 %
# Break and Enter Residential/Other                        12.84 %
# Other Theft                                              11.00 %
# Theft of Vehicle                                          8.09 %
# Break and Enter Commercial                                7.14 %
# Theft of Bicycle                                          5.40 %
# Vehicle Collision or Pedestrian Struck (with Injury)      4.62 %
# Vehicle Collision or Pedestrian Struck (with Fatality)    0.05 %

# %% [markdown]
# From the above calculations, it can be seen that the top few crimes make up the bulk of this dataset. So, in order to create a more focused model, we will take the top 4 of 9 crimes. The reasoning behind this is that these 4 crimes each make up more than 10% of the dataset and together they make up (36.05 + 14.80 + 12.84 + 11.00) = 74.69% of the dataset. Thus, we will remove the bottom 5 crimes from the dataset.

# %%
crimes = crimes[(crimes.TYPE == 'Theft from Vehicle') | (crimes.TYPE == 'Mischief') | (crimes.TYPE == 'Break and Enter Residential/Other') | (crimes.TYPE == 'Other Theft')]
display(crimes)
# Out:
#                                      TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0                             Other Theft  2003      5   12  16.0    15.0
# 1                             Other Theft  2003      5    7  15.0    20.0
# 2                             Other Theft  2003      4   23  16.0    40.0
# 3                             Other Theft  2003      4   20  11.0    15.0
# 4                             Other Theft  2003      4   12  17.0    45.0
# ...                                   ...   ...    ...  ...   ...     ...
# 530645  Break and Enter Residential/Other  2017      6   17  12.0    29.0
# 530646                           Mischief  2017      1   18  14.0    44.0
# 530647  Break and Enter Residential/Other  2017      3    3   9.0    16.0
# 530648                           Mischief  2017      5   29  22.0    30.0
# 530650                 Theft from Vehicle  2017      6    5  17.0     0.0
#
#              HUNDRED_BLOCK              NEIGHBOURHOOD          X           Y  \
# 0         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 1         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 2         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 3         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 4         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# ...                    ...                        ...        ...         ...
# 530645      30XX W 7TH AVE                  Kitsilano  487435.85  5457028.69
# 530646  14XX E HASTINGS ST         Grandview-Woodland  494563.75  5458727.40
# 530647      31XX ADANAC ST           Hastings-Sunrise  497265.49  5458296.71
# 530648      14XX E 7TH AVE         Grandview-Woodland  494533.97  5456824.97
# 530650     8XX HAMILTON ST  Central Business District  491487.85  5458385.78
#
#          Latitude   Longitude
# 0       49.269802 -123.083763
# 1       49.269802 -123.083763
# 2       49.269802 -123.083763
# 3       49.269802 -123.083763
# 4       49.269802 -123.083763
# ...           ...         ...
# 530645  49.265891 -123.172697
# 530646  49.281276 -123.074746
# 530647  49.277420 -123.037595
# 530648  49.264163 -123.075129
# 530650  49.278168 -123.117031
#
# [354062 rows x 12 columns]

# %% [markdown]
# Some data can have further information extracted from it. In our case, extracting a DayOfWeek (values 1-7 for Monday-Sunday) and WeekOfYear (1-53) attribute may help in producing more accurate predicitions. In order to do so, we will also have to convert the HOUR and MINUTE values from floats to ints.

# %%
crimes = crimes.astype({"HOUR": int, "MINUTE": int})

# %%
crime_dayofweek = []
crime_weekofyear = []
for i, r in crimes.iterrows():
    crime_datetime = datetime(r['YEAR'], r['MONTH'], r['DAY'], r['HOUR'], r['MINUTE'])
    crime_dayofweek.append(crime_datetime.isocalendar()[2])
    crime_weekofyear.append(crime_datetime.isocalendar()[1])
crimes.insert(6, 'DayOfWeek', crime_dayofweek)
crimes.insert(7, 'WeekOfYear', crime_weekofyear)
display(crimes)
# Out:
#                                      TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0                             Other Theft  2003      5   12    16      15
# 1                             Other Theft  2003      5    7    15      20
# 2                             Other Theft  2003      4   23    16      40
# 3                             Other Theft  2003      4   20    11      15
# 4                             Other Theft  2003      4   12    17      45
# ...                                   ...   ...    ...  ...   ...     ...
# 530645  Break and Enter Residential/Other  2017      6   17    12      29
# 530646                           Mischief  2017      1   18    14      44
# 530647  Break and Enter Residential/Other  2017      3    3     9      16
# 530648                           Mischief  2017      5   29    22      30
# 530650                 Theft from Vehicle  2017      6    5    17       0
#
#         DayOfWeek  WeekOfYear       HUNDRED_BLOCK              NEIGHBOURHOOD  \
# 0               1          20    9XX TERMINAL AVE                 Strathcona
# 1               3          19    9XX TERMINAL AVE                 Strathcona
# 2               3          17    9XX TERMINAL AVE                 Strathcona
# 3               7          16    9XX TERMINAL AVE                 Strathcona
# 4               6          15    9XX TERMINAL AVE                 Strathcona
# ...           ...         ...                 ...                        ...
# 530645          6          24      30XX W 7TH AVE                  Kitsilano
# 530646          3           3  14XX E HASTINGS ST         Grandview-Woodland
# 530647          5           9      31XX ADANAC ST           Hastings-Sunrise
# 530648          1          22      14XX E 7TH AVE         Grandview-Woodland
# 530650          1          23     8XX HAMILTON ST  Central Business District
#
#                 X           Y   Latitude   Longitude
# 0       493906.50  5457452.47  49.269802 -123.083763
# 1       493906.50  5457452.47  49.269802 -123.083763
# 2       493906.50  5457452.47  49.269802 -123.083763
# 3       493906.50  5457452.47  49.269802 -123.083763
# 4       493906.50  5457452.47  49.269802 -123.083763
# ...           ...         ...        ...         ...
# 530645  487435.85  5457028.69  49.265891 -123.172697
# 530646  494563.75  5458727.40  49.281276 -123.074746
# 530647  497265.49  5458296.71  49.277420 -123.037595
# 530648  494533.97  5456824.97  49.264163 -123.075129
# 530650  491487.85  5458385.78  49.278168 -123.117031
#
# [354062 rows x 14 columns]

# %% [markdown]
# In order to make this dataset compatible with the algorithms we will be using, we need to convert the crime types to numerical values (Theft from Vehicle = 0, Mischief = 1, Break and Enter Residential/Other = 2, Other Theft = 3).

# %%
crimes['TYPE'].replace(['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], [0, 1, 2, 3], inplace=True)
display(crimes)
# Out:
#         TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear  \
# 0          3  2003      5   12    16      15          1          20
# 1          3  2003      5    7    15      20          3          19
# 2          3  2003      4   23    16      40          3          17
# 3          3  2003      4   20    11      15          7          16
# 4          3  2003      4   12    17      45          6          15
# ...      ...   ...    ...  ...   ...     ...        ...         ...
# 530645     2  2017      6   17    12      29          6          24
# 530646     1  2017      1   18    14      44          3           3
# 530647     2  2017      3    3     9      16          5           9
# 530648     1  2017      5   29    22      30          1          22
# 530650     0  2017      6    5    17       0          1          23
#
#              HUNDRED_BLOCK              NEIGHBOURHOOD          X           Y  \
# 0         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 1         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 2         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 3         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# 4         9XX TERMINAL AVE                 Strathcona  493906.50  5457452.47
# ...                    ...                        ...        ...         ...
# 530645      30XX W 7TH AVE                  Kitsilano  487435.85  5457028.69
# 530646  14XX E HASTINGS ST         Grandview-Woodland  494563.75  5458727.40
# 530647      31XX ADANAC ST           Hastings-Sunrise  497265.49  5458296.71
# 530648      14XX E 7TH AVE         Grandview-Woodland  494533.97  5456824.97
# 530650     8XX HAMILTON ST  Central Business District  491487.85  5458385.78
#
#          Latitude   Longitude
# 0       49.269802 -123.083763
# 1       49.269802 -123.083763
# 2       49.269802 -123.083763
# 3       49.269802 -123.083763
# 4       49.269802 -123.083763
# ...           ...         ...
# 530645  49.265891 -123.172697
# 530646  49.281276 -123.074746
# 530647  49.277420 -123.037595
# 530648  49.264163 -123.075129
# 530650  49.278168 -123.117031
#
# [354062 rows x 14 columns]

# %% [markdown]
# Removing any remaining categorical data so that we can work with strictly numerical data.

# %%
crimes.pop('HUNDRED_BLOCK') 
crimes.pop('NEIGHBOURHOOD')
# Out:
# 0                        Strathcona
# 1                        Strathcona
# 2                        Strathcona
# 3                        Strathcona
# 4                        Strathcona
#                     ...
# 530645                    Kitsilano
# 530646           Grandview-Woodland
# 530647             Hastings-Sunrise
# 530648           Grandview-Woodland
# 530650    Central Business District
# Name: NEIGHBOURHOOD, Length: 354062, dtype: object

# %% [markdown]
# Now, we will split the dataset into 2 sets. The first dataset is the dataset being used to train up the model. The second dataset is the dataset which will be used for evaluating accuracy of the algorithm. These will be split up psuedorandomly in order to have a "random" split that will be consistent every time the code is run. The first step in doing this is to split the dataset into the features to look at and the target which will be predicted. The second step is to split the overall dataset into train and test sections.

# %%
features = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'DayOfWeek', 'WeekOfYear', 'X', 'Y', 'Latitude', 'Longitude']
X = crimes.loc[:, features]
target = ['TYPE']
Y = crimes.loc[:, target]
display(X)
display(Y)
# Out:
#         YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 0       2003      5   12    16      15          1          20  493906.50
# 1       2003      5    7    15      20          3          19  493906.50
# 2       2003      4   23    16      40          3          17  493906.50
# 3       2003      4   20    11      15          7          16  493906.50
# 4       2003      4   12    17      45          6          15  493906.50
# ...      ...    ...  ...   ...     ...        ...         ...        ...
# 530645  2017      6   17    12      29          6          24  487435.85
# 530646  2017      1   18    14      44          3           3  494563.75
# 530647  2017      3    3     9      16          5           9  497265.49
# 530648  2017      5   29    22      30          1          22  494533.97
# 530650  2017      6    5    17       0          1          23  491487.85
#
#                  Y   Latitude   Longitude
# 0       5457452.47  49.269802 -123.083763
# 1       5457452.47  49.269802 -123.083763
# 2       5457452.47  49.269802 -123.083763
# 3       5457452.47  49.269802 -123.083763
# 4       5457452.47  49.269802 -123.083763
# ...            ...        ...         ...
# 530645  5457028.69  49.265891 -123.172697
# 530646  5458727.40  49.281276 -123.074746
# 530647  5458296.71  49.277420 -123.037595
# 530648  5456824.97  49.264163 -123.075129
# 530650  5458385.78  49.278168 -123.117031
#
# [354062 rows x 11 columns]
#         TYPE
# 0          3
# 1          3
# 2          3
# 3          3
# 4          3
# ...      ...
# 530645     2
# 530646     1
# 530647     2
# 530648     1
# 530650     0
#
# [354062 rows x 1 columns]

# %%
# Splitting the dataset into test and train sections. 75% going to train and 25% going to test.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 0, train_size = .75)
display(X_train)
display(X_test)
display(Y_train)
display(Y_test)
# Out:
#         YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 160946  2006      4    1    15       0          6          13  491259.23
# 508344  2016      6    1    17       0          3          22  495148.02
# 348814  2011     12   19    15       0          1          51  490247.74
# 74383   2004      1   13    15      43          2           3  491827.08
# 359096  2012      2   29    18      16          3           9  491295.24
# ...      ...    ...  ...   ...     ...        ...         ...        ...
# 184432  2006      2   19    19      37          7           7  492220.96
# 457333  2015      8    6    13      30          4          32  491407.74
# 228945  2008      7    4     7       0          5          27  489876.35
# 175655  2006     11    6    17      32          1          45  491394.12
# 459585  2015     12    4     8      30          5          49  491480.63
#
#                  Y   Latitude   Longitude
# 160946  5459007.75  49.283760 -123.120188
# 508344  5454528.42  49.243511 -123.066661
# 348814  5456234.11  49.258795 -123.134028
# 74383   5459079.55  49.284414 -123.112381
# 359096  5458744.77  49.281395 -123.119687
# ...            ...        ...         ...
# 184432  5456883.18  49.264662 -123.106922
# 457333  5458871.84  49.282539 -123.118143
# 228945  5450301.37  49.205423 -123.138982
# 175655  5458844.26  49.282291 -123.118329
# 459585  5458792.38  49.281826 -123.117139
#
# [265546 rows x 11 columns]
#         YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 50989   2004      1    8    20       0          4           2  488974.18
# 93153   2004      9   30    20       0          4          40  491651.57
# 285997  2009      6   26    18       0          5          26  493681.15
# 398506  2013      8    7    16       0          3          32  491355.26
# 331370  2011      5   16    20      16          1          20  490797.66
# ...      ...    ...  ...   ...     ...        ...         ...        ...
# 462265  2015     10   24     0       0          6          43  490116.26
# 7976    2003      9   22    23       0          1          39  490092.82
# 56138   2004      3   10    17      15          3          11  495041.52
# 46218   2003      7   17    17       0          4          29  489997.09
# 414370  2014      5   13    18      40          2          20  491593.15
#
#                  Y   Latitude   Longitude
# 50989   5457668.25  49.271674 -123.151570
# 93153   5458615.15  49.280234 -123.114785
# 285997  5458813.86  49.282046 -123.086883
# 398506  5460631.89  49.298371 -123.118902
# 331370  5459282.31  49.286223 -123.126541
# ...            ...        ...         ...
# 462265  5459123.65  49.284785 -123.135906
# 7976    5459451.96  49.287738 -123.136237
# 56138   5458609.51  49.280220 -123.068175
# 46218   5456450.44  49.260737 -123.137478
# 414370  5459475.93  49.287976 -123.115606
#
# [88516 rows x 11 columns]
#         TYPE
# 160946     0
# 508344     2
# 348814     0
# 74383      3
# 359096     3
# ...      ...
# 184432     1
# 457333     3
# 228945     2
# 175655     3
# 459585     0
#
# [265546 rows x 1 columns]
#         TYPE
# 50989      2
# 93153      0
# 285997     0
# 398506     0
# 331370     3
# ...      ...
# 462265     0
# 7976       1
# 56138      1
# 46218      0
# 414370     1
#
# [88516 rows x 1 columns]

# %% [markdown]
# Before we begin processing the data, we will display our classes for the implemented algorithms.

# %% [markdown]
# Naive Bayes

# %%
class NaiveBayes:
    
    def NBpredict(self, A):
        yARG = [self._NBpredict(a) for a in A]#This will itterate through every posibility of a that will be used to calculate P(a[1..n]|b)
        return np.array(yARG)#Note: the return must be an array for the accuracy calculation. I over looked this and took 45 mins to correct :(
   
        
    def _NBpredict(self, a): #You need this function because for some reason you are not able to nest the for loops with a in A. Thus we make a second function
        pAB_values = [] #Stores all the possible answers of our probibility calculations 
        for i in range(len(self._classes)):
            j = self._classes[i] #Going through the array of unique values
            prior = np.log(self._priors[i])
            pAB = np.sum(np.log(self.NPgaussian(i, a)))
            pAB = pAB + prior
            pAB_values.append(pAB)

        return self._classes[np.argmax(pAB_values)] # return the highest P(A|B) to the calling function
    
    def NPgaussian(self, index, a):
        meanNew = self._mean[index] #Select the mean at the given index from our FIT
        varNew = self._var[index] #Select the variance at the given index from our FIT
        
        #Make a fancy mathematical expression for the gaussian equation calculation
        numerator = 1 * np.exp(-((a - meanNew) ** 2) / (2 * varNew))
        denominator = varNew * np.sqrt(2 * np.pi)
        
        return (numerator/denominator) 
    
    def NBfit(self, A, b):
        #assignes the integer value of rows to NumRows and the integer value of columbs to numCol
        numRows = A.shape[0]
        numCol = A.shape[1]
        #specific classifier of the class = find the unique elements of an array and return that array sorted to us
        self._classes = np.unique(b)
        #will return the number of classes (ie the lenght of the class identifier that is unique)
        numClass = len(self._classes)
    
        #We calculate the mean, variance and frequency for each unique columb , data type is numpy float64 bit (dtype = np.float64)
        self._mean = np.zeros((numClass, numCol)) #Creates a zero filled matrix of size numClass x numCol
        self._var = np.zeros((numClass, numCol)) #Creates a zero filled matrix of size numClass x numCol
        self._priors = np.zeros(numClass) #Creates a zero filled array/1D matrix of size numClass
    
        #This loop will actually do the calculating of the above zero matrices
        for i in range(numClass):
            j = self._classes[i] #Going through the array of unique values
            classXj = A[b == j] #The base array of crime type == index selected value of crime type - calculate and store in the zero matrix above
            self._mean[i,] = classXj.mean()
            self._var[i,] = classXj.var()
            self._priors[i] = classXj.shape[0] / float(numRows) #Number of unique rows we have divided by the total number of rows we have

# %% [markdown]
# Recursive Feature Elimination

# %%
# Simplified class for Recursive Feature Elimination that uses RandomForestClassifier
class Recursive_Feature_Elimination:
    
    # Initiailize object with the desired number of features to select and the step size
    # The step size determines how many features to drop per iteration of the algorithm
    def __init__(self, n_features_to_select = 0, step = 1):
        self.estimator_ = RandomForestClassifier() # Estimator used for the class: set to RandomForestClassifer
        self.n_features_to_select_ = n_features_to_select # Number of features being selected
        self.step_ = step # Step size
        self.n_features_ = 0 # The number of features selected
        self.ranking_ = [] # Rank of features: chosen features are 1, and non-chosen numbers are ranked from 2 - number of features in the dataset
        self.support_ = [] # Boolean representation of ranking: chosen features are True, non-chosen features are False
    
    # Function that actually performs the Recursive Feature Elimination
    # Calls fit on the estimator recursively to find feature importances and removes unimportant features until only the desired number of features remain
    def fit(self, X, y):
        if self.n_features_to_select_ <= 0: # If n_features_to_select_ is set <= 0: default it to half the size of X
            self.n_features_to_select_ = math.ceil(len(X.columns) / 2)
        self.n_features_ = len(X.columns) # Set n_features_ to the number of features in X
        self.ranking_ = np.zeros(self.n_features_) # Initialize ranking_ to an array of zeros of size n_features_
        self.support_ = np.array([False] * self.n_features_) # Initialize support_ to an arry of False's of size n_features_
        X_copy = X.copy() # Copy X so that we do not modify it in our calculations
        while (self.n_features_ > self.n_features_to_select_):
            self.estimator_.fit(X_copy, y) # Call the fit function of the estimator object
            fi = self.estimator_.feature_importances_ # Store feature_importances_ from most recent call of fit in fi
            for i in range(self.step_): # Remove step_ amount of features for next calculation and mark their rank
                if self.n_features_ > self.n_features_to_select_: # Only perform these steps if it will not remove needed features
                    lowest_feature_loc = X.columns.get_loc(X_copy.columns[np.argmin(fi)]) # Index in ranking_ of the least important feature
                    self.ranking_[lowest_feature_loc] = self.n_features_ - self.n_features_to_select_ + 1 # Assign rank for least important feature to its index in ranking_
                    X_copy.drop(X_copy.columns[np.argmin(fi)], axis = 1, inplace = True) # Drop least important feature from X_copy
                    fi = np.delete(fi, np.argmin(fi)) # Remove least important feature from feature importance array
                    self.n_features_ = len(X_copy.columns) # Update n_features_
        self.ranking_[self.ranking_ < 1] = 1 # Mark all remaining features as 1
        for i in range(len(self.support_)): # Update support_ to be True at each index that ranking_ is 1
            if self.ranking_[i] == 1:
                self.support_[i] = True
        
    # Reduces the X to only contain the important columns as determined by the fit function
    def transform(self, X):
        X_copy = X.copy() # Copy X so that it is not modified
        for i in range(len(self.ranking_)): # Drop unimportant features from X_copy
            if self.support_[i] != True:
                X_copy.drop(X.columns[i], axis = 1, inplace = True)
        return X_copy # Return the modified version of X
    
    # Calls fit on X and y, then transforms X and returns it
    def fit_transform(self, X, y):
        self.fit(X, y)
        new_data = self.transform(X)
        return new_data

# %% [markdown]
# First, we will compare our implementation of Naive Bayes to the implementation found in SKLearn based on accuracy.

# %% [markdown]
# SKLearn

# %%
accuracy = []
precision = []
recall = []
f1 = []

# %%
gnb = GaussianNB()
gnb.fit(X_train, Y_train.values.ravel())
Y_pred = gnb.predict(X_test)
Y_predSKNB = Y_pred.copy()

accuracy.append(accuracy_score(Y_test, Y_pred))
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))

# %% [markdown]
# Ours

# %%
gnb = NaiveBayes()
gnb.NBfit(X_train, Y_train.values.ravel())
X_test2 = X_test.to_numpy()
Y_pred = gnb.NBpredict(X_test2)
Y_predNB = Y_pred.copy()

accuracy.append(accuracy_score(Y_test, Y_pred)) 
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))

# %% [markdown]
# Next, we will compare our version of Recursive Feature Elimination to the one in SKLearn.

# %% [markdown]
# SKLearn

# %%
estimator = RandomForestClassifier()
selector_SK = RFE(estimator)
selector_SK = selector_SK.fit(X_train, Y_train.values.ravel())
display(selector_SK.ranking_)
display(selector_SK.support_)
# Out:
# array([5, 7, 4, 3, 2, 6, 1, 1, 1, 1, 1])
# array([False, False, False, False, False, False,  True,  True,  True,
#         True,  True])

# %% [markdown]
# Now that we have the optimal number of features and the results from SKLearn RFE, we will use the number of features with our own RFE algorihtm.

# %% [markdown]
# Ours

# %%
selector_OU = Recursive_Feature_Elimination()
selector_OU.fit(X_train, Y_train.values.ravel())
display(selector_OU.ranking_)
display(selector_OU.support_)
# Out:
# array([4., 6., 3., 2., 1., 5., 1., 1., 1., 1., 1.])
# array([False, False, False, False,  True, False,  True,  True,  True,
#         True,  True])

# %% [markdown]
# From here, we will transform X_test and X_train using the SKLearn RFE and see its effects on both implementations of Naive Bayes.

# %%
X_test_SK = selector_SK.transform(X_test)
X_train_SK = selector_SK.transform(X_train)

# %% [markdown]
# SKLearn

# %%
gnb = GaussianNB()
gnb.fit(X_train_SK, Y_train.values.ravel())
Y_pred = gnb.predict(X_test_SK)

accuracy.append(accuracy_score(Y_test, Y_pred)) 
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Ours

# %%
gnb = NaiveBayes()
gnb.NBfit(X_train_SK, Y_train.values.ravel())
Y_pred = gnb.NBpredict(X_test_SK)

accuracy.append(accuracy_score(Y_test, Y_pred)) 
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Now, we will transform X_test and X_train using our implementation of RFE and see its effects on both implementations of Naive Bayes.

# %%
X_test_OU = selector_OU.transform(X_test)
X_train_OU = selector_OU.transform(X_train)

# %% [markdown]
# SKLearn

# %%
gnb = GaussianNB()
gnb.fit(X_train_OU, Y_train.values.ravel())
Y_pred = gnb.predict(X_test_OU)
Y_predSKRFE = Y_pred.copy()

accuracy.append(accuracy_score(Y_test, Y_pred)) 
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))

# %% [markdown]
# Ours

# %%
gnb = NaiveBayes()
gnb.NBfit(X_train_OU, Y_train.values.ravel())
X_test_OU2 = X_test_OU.to_numpy()
Y_pred = gnb.NBpredict(X_test_OU2)
Y_predRFE = Y_pred.copy()

accuracy.append(accuracy_score(Y_test, Y_pred)) 
precision.append(precision_score(Y_test, Y_pred, average='macro'))
recall.append(recall_score(Y_test, Y_pred, average='macro'))
f1.append(f1_score(Y_test, Y_pred, average='macro'))

# %% [markdown]
# Here we have a comparsion of all the different combinations according to the metrics: accuracy, precision, recall, and F1 Score.

# %%
index_values = ['Accuracy', 'Precision', 'Recall', 'F1_Score']
column_values = ['SK NB', 'Our NB', 'SK NB w/ SK RFE', 'Our NB w/ SK RFE', 'SK NB w/ Our RFE', 'Our NB w/ Our RFE']
metrics = pd.DataFrame(data = [accuracy, precision, recall, f1], index=index_values, columns=column_values)
metrics
# Out:
#               SK NB    Our NB  SK NB w/ SK RFE  Our NB w/ SK RFE  \
# Accuracy   0.493628  0.436023         0.465498          0.480840
# Precision  0.412902  0.404622         0.181253          0.120210
# Recall     0.356008  0.390670         0.256250          0.250000
# F1_Score   0.341525  0.331569         0.191399          0.162354
#
#            SK NB w/ Our RFE  Our NB w/ Our RFE
# Accuracy           0.479631           0.425618
# Precision          0.347540           0.331506
# Recall             0.318783           0.332515
# F1_Score           0.288146           0.290744

# %% [markdown]
# We will now join Y_pred, Y_test, and X_test to see a snapshot of the predictions versus the actual results from both our Naive Bayes algorithm and our Naive Bayes algorithm with Recursive Feature Elimination.

# %%
Y_predNB = pd.DataFrame(Y_predNB)
Y_predNB.columns = ["Predicted Type"]
Y_predNB.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
Y_predRFE = pd.DataFrame(Y_predRFE)
Y_predRFE.columns = ["Predicted Type"]
Y_predRFE.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
Y_test.columns = ["Actual Type"]
Y_test.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
NB = pd.concat([Y_predNB.reset_index(drop=True) ,Y_test.reset_index(drop=True), X_test.reset_index(drop=True)], axis=1)
RFE = pd.concat([Y_predRFE.reset_index(drop=True) ,Y_test.reset_index(drop=True), X_test.reset_index(drop=True)], axis=1)

# %% [markdown]
# First, we will list Predictions vs Actual on Theft from Vehicle.

# %%
display("Original Naive Bayes: Theft from Vehicle", NB[NB['Predicted Type'] == "Theft from Vehicle"])
display("Naive Bayes with Recursive Feature Elimination: Theft from Vehicle", RFE[RFE['Predicted Type'] == "Theft from Vehicle"])
# Out:
# 'Original Naive Bayes: Theft from Vehicle'
#            Predicted Type                        Actual Type  YEAR  MONTH  \
# 0      Theft from Vehicle  Break and Enter Residential/Other  2004      1
# 1      Theft from Vehicle                 Theft from Vehicle  2004      9
# 2      Theft from Vehicle                 Theft from Vehicle  2009      6
# 3      Theft from Vehicle                 Theft from Vehicle  2013      8
# 6      Theft from Vehicle                 Theft from Vehicle  2005      6
# ...                   ...                                ...   ...    ...
# 88507  Theft from Vehicle                 Theft from Vehicle  2014     11
# 88510  Theft from Vehicle                        Other Theft  2015     10
# 88511  Theft from Vehicle                 Theft from Vehicle  2015     10
# 88512  Theft from Vehicle                           Mischief  2003      9
# 88514  Theft from Vehicle                 Theft from Vehicle  2003      7
#
#        DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y  \
# 0        8    20       0          4           2  488974.18  5457668.25
# 1       30    20       0          4          40  491651.57  5458615.15
# 2       26    18       0          5          26  493681.15  5458813.86
# 3        7    16       0          3          32  491355.26  5460631.89
# 6       27    19       0          1          26  489359.90  5457818.89
# ...    ...   ...     ...        ...         ...        ...         ...
# 88507   30    17       0          7          48  491008.90  5458315.77
# 88510    7     7       8          3          41  497308.77  5456155.92
# 88511   24     0       0          6          43  490116.26  5459123.65
# 88512   22    23       0          1          39  490092.82  5459451.96
# 88514   17    17       0          4          29  489997.09  5456450.44
#
#         Latitude   Longitude
# 0      49.271674 -123.151570
# 1      49.280234 -123.114785
# 2      49.282046 -123.086883
# 3      49.298371 -123.118902
# 6      49.273036 -123.146272
# ...          ...         ...
# 88507  49.277532 -123.123614
# 88510  49.258164 -123.036986
# 88511  49.284785 -123.135906
# 88512  49.287738 -123.136237
# 88514  49.260737 -123.137478
#
# [45217 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Theft from Vehicle'
#            Predicted Type                        Actual Type  YEAR  MONTH  \
# 0      Theft from Vehicle  Break and Enter Residential/Other  2004      1
# 1      Theft from Vehicle                 Theft from Vehicle  2004      9
# 2      Theft from Vehicle                 Theft from Vehicle  2009      6
# 3      Theft from Vehicle                 Theft from Vehicle  2013      8
# 4      Theft from Vehicle                        Other Theft  2011      5
# ...                   ...                                ...   ...    ...
# 88510  Theft from Vehicle                        Other Theft  2015     10
# 88511  Theft from Vehicle                 Theft from Vehicle  2015     10
# 88512  Theft from Vehicle                           Mischief  2003      9
# 88513  Theft from Vehicle                           Mischief  2004      3
# 88514  Theft from Vehicle                 Theft from Vehicle  2003      7
#
#        DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y  \
# 0        8    20       0          4           2  488974.18  5457668.25
# 1       30    20       0          4          40  491651.57  5458615.15
# 2       26    18       0          5          26  493681.15  5458813.86
# 3        7    16       0          3          32  491355.26  5460631.89
# 4       16    20      16          1          20  490797.66  5459282.31
# ...    ...   ...     ...        ...         ...        ...         ...
# 88510    7     7       8          3          41  497308.77  5456155.92
# 88511   24     0       0          6          43  490116.26  5459123.65
# 88512   22    23       0          1          39  490092.82  5459451.96
# 88513   10    17      15          3          11  495041.52  5458609.51
# 88514   17    17       0          4          29  489997.09  5456450.44
#
#         Latitude   Longitude
# 0      49.271674 -123.151570
# 1      49.280234 -123.114785
# 2      49.282046 -123.086883
# 3      49.298371 -123.118902
# 4      49.286223 -123.126541
# ...          ...         ...
# 88510  49.258164 -123.036986
# 88511  49.284785 -123.135906
# 88512  49.287738 -123.136237
# 88513  49.280220 -123.068175
# 88514  49.260737 -123.137478
#
# [54165 rows x 13 columns]

# %% [markdown]
# Next, we will list Predictions vs Actual on Mischief.

# %%
display("Original Naive Bayes: Mischief", NB[NB['Predicted Type'] == "Mischief"])
display("Naive Bayes with Recursive Feature Elimination: Mischief", RFE[RFE['Predicted Type'] == "Mischief"])
# Out:
# 'Original Naive Bayes: Mischief'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 32          Mischief                           Mischief  2015      1   17
# 37          Mischief                           Mischief  2009      2   17
# 63          Mischief                           Mischief  2008      8   21
# 126         Mischief  Break and Enter Residential/Other  2013      8   29
# 132         Mischief                           Mischief  2012      9   11
# ...              ...                                ...   ...    ...  ...
# 88065       Mischief  Break and Enter Residential/Other  2011      5   11
# 88130       Mischief                 Theft from Vehicle  2008      2   17
# 88214       Mischief                 Theft from Vehicle  2017      5   21
# 88413       Mischief                 Theft from Vehicle  2013     10   12
# 88426       Mischief                           Mischief  2013      8   23
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 32        1      53          6           3  490470.88  5458197.99  49.276464
# 37        2      30          2           8  496297.61  5458207.06  49.276609
# 63        1      50          4          34  489905.08  5456038.01  49.257026
# 126       2      47          4          35  492726.16  5458199.65  49.276510
# 132       4      55          2          37  496210.84  5456579.20  49.261965
# ...     ...     ...        ...         ...        ...         ...        ...
# 88065     1      48          3          19  492192.12  5457576.84  49.270901
# 88130     0      30          7           7  495083.83  5457524.49  49.270460
# 88214     6      35          7          20  498073.38  5456160.71  49.258210
# 88413     1      30          6          41  494830.61  5456932.79  49.265136
# 88426     1      40          5          34  493177.29  5453039.25  49.230096
#
#         Longitude
# 32    -123.131008
# 37    -123.050901
# 63    -123.138732
# 126   -123.100002
# 132   -123.052079
# ...           ...
# 88065 -123.107332
# 88130 -123.067580
# 88214 -123.026478
# 88413 -123.071054
# 88426 -123.093712
#
# [1327 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Mischief'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 160         Mischief                        Other Theft  2008      8    5
# 554         Mischief                 Theft from Vehicle  2016      8    6
# 699         Mischief                        Other Theft  2008      5   15
# 1205        Mischief  Break and Enter Residential/Other  2011      6   23
# 1595        Mischief                           Mischief  2008      6   10
# ...              ...                                ...   ...    ...  ...
# 87329       Mischief                        Other Theft  2005      2   16
# 87540       Mischief                        Other Theft  2003     11   26
# 87666       Mischief                           Mischief  2003      9   12
# 87859       Mischief                           Mischief  2008      2    9
# 88393       Mischief                        Other Theft  2011      8   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 160      10      55          2          32  493399.03  5452635.98  49.226471
# 554      21      35          6          31  498186.19  5458384.70  49.278215
# 699      19      57          4          20  492603.78  5452467.75  49.224949
# 1205     18      49          4          25  497227.78  5455512.38  49.252375
# 1595      5      48          2          24  494380.79  5453316.85  49.232606
# ...     ...     ...        ...         ...        ...         ...        ...
# 87329    12      55          3           7  493391.44  5452727.13  49.227291
# 87540    20      43          3          48  495513.37  5454530.92  49.243536
# 87666    22      40          5          37  498106.86  5458704.55  49.281092
# 87859    18      41          6           6  497807.78  5456721.84  49.263256
# 88393    16      52          6          32  493397.06  5452944.43  49.229246
#
#         Longitude
# 160   -123.090660
# 554   -123.024937
# 699   -123.101579
# 1205  -123.038094
# 1595  -123.077186
# ...           ...
# 87329 -123.090766
# 87540 -123.061642
# 87666 -123.026030
# 87859 -123.030131
# 88393 -123.090692
#
# [345 rows x 13 columns]

# %% [markdown]
# Next, we will list Predictions vs Actual on Break and Enter Residential/Other.

# %%
display("Original Naive Bayes: Break and Enter Residential/Other", NB[NB['Predicted Type'] == "Break and Enter Residential/Other"])
display("Naive Bayes with Recursive Feature Elimination: Break and Enter Residential/Other", RFE[RFE['Predicted Type'] == "Break and Enter Residential/Other"])
# Out:
# 'Original Naive Bayes: Break and Enter Residential/Other'
#                           Predicted Type                        Actual Type  \
# 11     Break and Enter Residential/Other                 Theft from Vehicle
# 15     Break and Enter Residential/Other                           Mischief
# 16     Break and Enter Residential/Other                 Theft from Vehicle
# 21     Break and Enter Residential/Other  Break and Enter Residential/Other
# 22     Break and Enter Residential/Other  Break and Enter Residential/Other
# ...                                  ...                                ...
# 88473  Break and Enter Residential/Other                           Mischief
# 88474  Break and Enter Residential/Other                        Other Theft
# 88478  Break and Enter Residential/Other                 Theft from Vehicle
# 88497  Break and Enter Residential/Other                 Theft from Vehicle
# 88501  Break and Enter Residential/Other                 Theft from Vehicle
#
#        YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 11     2005      2   18    18       0          5           7  489537.22
# 15     2007     10   11     1      41          4          41  490750.27
# 16     2005      8   15    16      30          1          33  490186.83
# 21     2006      1    2     1      30          1           1  494653.13
# 22     2007      2    5     9       0          1           6  496487.36
# ...     ...    ...  ...   ...     ...        ...         ...        ...
# 88473  2013      4   27    19      54          6          17  498038.64
# 88474  2009      1   28    20      31          3           5  489762.32
# 88478  2004      7   13    19       0          2          29  498245.72
# 88497  2008      5   11     3      15          7          19  494995.46
# 88501  2006      2   15    14      10          3           7  492648.10
#
#                 Y   Latitude   Longitude
# 11     5451258.02  49.214022 -123.143663
# 15     5450638.13  49.208466 -123.126993
# 16     5450074.65  49.203389 -123.134714
# 21     5452495.27  49.225218 -123.073434
# 22     5454838.51  49.246309 -123.048263
# ...           ...        ...         ...
# 88473  5453379.95  49.233196 -123.026942
# 88474  5450762.71  49.209571 -123.140560
# 88478  5455410.44  49.251461 -123.024106
# 88497  5451114.71  49.212802 -123.068715
# 88501  5450886.95  49.210730 -123.100941
#
# [12385 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Break and Enter Residential/Other'
#                           Predicted Type                        Actual Type  \
# 11     Break and Enter Residential/Other                 Theft from Vehicle
# 15     Break and Enter Residential/Other                           Mischief
# 16     Break and Enter Residential/Other                 Theft from Vehicle
# 21     Break and Enter Residential/Other  Break and Enter Residential/Other
# 31     Break and Enter Residential/Other                           Mischief
# ...                                  ...                                ...
# 88478  Break and Enter Residential/Other                 Theft from Vehicle
# 88482  Break and Enter Residential/Other                 Theft from Vehicle
# 88497  Break and Enter Residential/Other                 Theft from Vehicle
# 88501  Break and Enter Residential/Other                 Theft from Vehicle
# 88502  Break and Enter Residential/Other                 Theft from Vehicle
#
#        YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 11     2005      2   18    18       0          5           7  489537.22
# 15     2007     10   11     1      41          4          41  490750.27
# 16     2005      8   15    16      30          1          33  490186.83
# 21     2006      1    2     1      30          1           1  494653.13
# 31     2005     11   19     4       0          6          46  485895.79
# ...     ...    ...  ...   ...     ...        ...         ...        ...
# 88478  2004      7   13    19       0          2          29  498245.72
# 88482  2011      2   26    20       0          6           8  496806.45
# 88497  2008      5   11     3      15          7          19  494995.46
# 88501  2006      2   15    14      10          3           7  492648.10
# 88502  2014      4   27    22       0          7          17  490184.29
#
#                 Y   Latitude   Longitude
# 11     5451258.02  49.214022 -123.143663
# 15     5450638.13  49.208466 -123.126993
# 16     5450074.65  49.203389 -123.134714
# 21     5452495.27  49.225218 -123.073434
# 31     5453328.33  49.232572 -123.193736
# ...           ...        ...         ...
# 88478  5455410.44  49.251461 -123.024106
# 88482  5453976.59  49.238558 -123.043872
# 88497  5451114.71  49.212802 -123.068715
# 88501  5450886.95  49.210730 -123.100941
# 88502  5450319.29  49.205589 -123.134755
#
# [11627 rows x 13 columns]

# %% [markdown]
# Finally, we will list Predictions vs Actual on Other Theft.

# %%
display("Original Naive Bayes: Other Theft", NB[NB['Predicted Type'] == "Other Theft"])
display("Naive Bayes with Recursive Feature Elimination: Other Theft", RFE[RFE['Predicted Type'] == "Other Theft"])
# Out:
# 'Original Naive Bayes: Other Theft'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 4        Other Theft                        Other Theft  2011      5   16
# 5        Other Theft                           Mischief  2015     12   28
# 10       Other Theft                 Theft from Vehicle  2008      7   19
# 17       Other Theft  Break and Enter Residential/Other  2007     10    1
# 19       Other Theft                 Theft from Vehicle  2014      4    6
# ...              ...                                ...   ...    ...  ...
# 88505    Other Theft                           Mischief  2006     10    8
# 88508    Other Theft                 Theft from Vehicle  2015     10   22
# 88509    Other Theft                 Theft from Vehicle  2011     10   10
# 88513    Other Theft                           Mischief  2004      3   10
# 88515    Other Theft                           Mischief  2014      5   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 4        20      16          1          20  490797.66  5459282.31  49.286223
# 5        15       3          1          53  494384.28  5458209.26  49.276614
# 10       18      47          6          29  491833.57  5459286.88  49.286279
# 17       17      15          1          40  490729.83  5458622.34  49.280285
# 19       18       0          7          14  493065.48  5458615.63  49.280256
# ...     ...     ...        ...         ...        ...         ...        ...
# 88505    14      45          7          40  496487.75  5458028.74  49.275006
# 88508    18       0          4          43  494935.90  5457413.51  49.269461
# 88509    22      30          1          41  492580.71  5458321.63  49.277606
# 88513    17      15          3          11  495041.52  5458609.51  49.280220
# 88515    18      40          2          20  491593.15  5459475.93  49.287976
#
#         Longitude
# 4     -123.126541
# 5     -123.077206
# 10    -123.112296
# 17    -123.127458
# 19    -123.095344
# ...           ...
# 88505 -123.048286
# 88508 -123.069612
# 88509 -123.102004
# 88513 -123.068175
# 88515 -123.115606
#
# [29587 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Other Theft'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 10       Other Theft                 Theft from Vehicle  2008      7   19
# 23       Other Theft                 Theft from Vehicle  2009     12   21
# 24       Other Theft                 Theft from Vehicle  2004      5   11
# 29       Other Theft                        Other Theft  2007      2   24
# 30       Other Theft                 Theft from Vehicle  2017      6   16
# ...              ...                                ...   ...    ...  ...
# 88492    Other Theft                 Theft from Vehicle  2008      5   25
# 88493    Other Theft  Break and Enter Residential/Other  2008      2   15
# 88505    Other Theft                           Mischief  2006     10    8
# 88509    Other Theft                 Theft from Vehicle  2011     10   10
# 88515    Other Theft                           Mischief  2014      5   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 10       18      47          6          29  491833.57  5459286.88  49.286279
# 23       11      56          1          52  490955.33  5459482.91  49.288030
# 24        7      30          2          20  492257.60  5458266.56  49.277106
# 29       14      43          6           8  491827.08  5459079.55  49.284414
# 30       18      35          5          24  490951.41  5456220.14  49.258680
# ...     ...     ...        ...         ...        ...         ...        ...
# 88492    23      30          7          21  493711.74  5458908.08  49.282894
# 88493    12      44          5           7  492627.03  5454817.01  49.246081
# 88505    14      45          7          40  496487.75  5458028.74  49.275006
# 88509    22      30          1          41  492580.71  5458321.63  49.277606
# 88515    18      40          2          20  491593.15  5459475.93  49.287976
#
#         Longitude
# 10    -123.112296
# 23    -123.124377
# 24    -123.106445
# 29    -123.112381
# 30    -123.124357
# ...           ...
# 88492 -123.086463
# 88493 -123.101303
# 88505 -123.048286
# 88509 -123.102004
# 88515 -123.115606
#
# [22379 rows x 13 columns]

# %% [markdown]
# We will now perform the same join using the SKLearn Naive Bayes with our implementation of Recursive Feature Elimination.

# %%
Y_predSKNB = pd.DataFrame(Y_predSKNB)
Y_predSKNB.columns = ["Predicted Type"]
Y_predSKNB.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
Y_predSKRFE = pd.DataFrame(Y_predSKRFE)
Y_predSKRFE.columns = ["Predicted Type"]
Y_predSKRFE.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
Y_test.columns = ["Actual Type"]
Y_test.replace([0, 1, 2, 3], ['Theft from Vehicle', 'Mischief', 'Break and Enter Residential/Other', 'Other Theft'], inplace=True)
SKNB = pd.concat([Y_predSKNB.reset_index(drop=True) ,Y_test.reset_index(drop=True), X_test.reset_index(drop=True)], axis=1)
SKRFE = pd.concat([Y_predSKRFE.reset_index(drop=True) ,Y_test.reset_index(drop=True), X_test.reset_index(drop=True)], axis=1)

# %%
display("Original Naive Bayes: Theft from Vehicle", SKNB[SKNB['Predicted Type'] == "Theft from Vehicle"])
display("Naive Bayes with Recursive Feature Elimination: Theft from Vehicle", SKRFE[SKRFE['Predicted Type'] == "Theft from Vehicle"])
# Out:
# 'Original Naive Bayes: Theft from Vehicle'
#            Predicted Type                        Actual Type  YEAR  MONTH  \
# 0      Theft from Vehicle  Break and Enter Residential/Other  2004      1
# 1      Theft from Vehicle                 Theft from Vehicle  2004      9
# 2      Theft from Vehicle                 Theft from Vehicle  2009      6
# 3      Theft from Vehicle                 Theft from Vehicle  2013      8
# 4      Theft from Vehicle                        Other Theft  2011      5
# ...                   ...                                ...   ...    ...
# 88510  Theft from Vehicle                        Other Theft  2015     10
# 88511  Theft from Vehicle                 Theft from Vehicle  2015     10
# 88512  Theft from Vehicle                           Mischief  2003      9
# 88513  Theft from Vehicle                           Mischief  2004      3
# 88514  Theft from Vehicle                 Theft from Vehicle  2003      7
#
#        DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y  \
# 0        8    20       0          4           2  488974.18  5457668.25
# 1       30    20       0          4          40  491651.57  5458615.15
# 2       26    18       0          5          26  493681.15  5458813.86
# 3        7    16       0          3          32  491355.26  5460631.89
# 4       16    20      16          1          20  490797.66  5459282.31
# ...    ...   ...     ...        ...         ...        ...         ...
# 88510    7     7       8          3          41  497308.77  5456155.92
# 88511   24     0       0          6          43  490116.26  5459123.65
# 88512   22    23       0          1          39  490092.82  5459451.96
# 88513   10    17      15          3          11  495041.52  5458609.51
# 88514   17    17       0          4          29  489997.09  5456450.44
#
#         Latitude   Longitude
# 0      49.271674 -123.151570
# 1      49.280234 -123.114785
# 2      49.282046 -123.086883
# 3      49.298371 -123.118902
# 4      49.286223 -123.126541
# ...          ...         ...
# 88510  49.258164 -123.036986
# 88511  49.284785 -123.135906
# 88512  49.287738 -123.136237
# 88513  49.280220 -123.068175
# 88514  49.260737 -123.137478
#
# [66201 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Theft from Vehicle'
#            Predicted Type                        Actual Type  YEAR  MONTH  \
# 0      Theft from Vehicle  Break and Enter Residential/Other  2004      1
# 1      Theft from Vehicle                 Theft from Vehicle  2004      9
# 2      Theft from Vehicle                 Theft from Vehicle  2009      6
# 3      Theft from Vehicle                 Theft from Vehicle  2013      8
# 4      Theft from Vehicle                        Other Theft  2011      5
# ...                   ...                                ...   ...    ...
# 88510  Theft from Vehicle                        Other Theft  2015     10
# 88511  Theft from Vehicle                 Theft from Vehicle  2015     10
# 88512  Theft from Vehicle                           Mischief  2003      9
# 88513  Theft from Vehicle                           Mischief  2004      3
# 88514  Theft from Vehicle                 Theft from Vehicle  2003      7
#
#        DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y  \
# 0        8    20       0          4           2  488974.18  5457668.25
# 1       30    20       0          4          40  491651.57  5458615.15
# 2       26    18       0          5          26  493681.15  5458813.86
# 3        7    16       0          3          32  491355.26  5460631.89
# 4       16    20      16          1          20  490797.66  5459282.31
# ...    ...   ...     ...        ...         ...        ...         ...
# 88510    7     7       8          3          41  497308.77  5456155.92
# 88511   24     0       0          6          43  490116.26  5459123.65
# 88512   22    23       0          1          39  490092.82  5459451.96
# 88513   10    17      15          3          11  495041.52  5458609.51
# 88514   17    17       0          4          29  489997.09  5456450.44
#
#         Latitude   Longitude
# 0      49.271674 -123.151570
# 1      49.280234 -123.114785
# 2      49.282046 -123.086883
# 3      49.298371 -123.118902
# 4      49.286223 -123.126541
# ...          ...         ...
# 88510  49.258164 -123.036986
# 88511  49.284785 -123.135906
# 88512  49.287738 -123.136237
# 88513  49.280220 -123.068175
# 88514  49.260737 -123.137478
#
# [70331 rows x 13 columns]

# %%
display("Original Naive Bayes: Mischief", SKNB[SKNB['Predicted Type'] == "Mischief"])
display("Naive Bayes with Recursive Feature Elimination: Mischief", SKRFE[SKRFE['Predicted Type'] == "Mischief"])
# Out:
# 'Original Naive Bayes: Mischief'
#       Predicted Type         Actual Type  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 32          Mischief            Mischief  2015      1   17     1      53
# 37          Mischief            Mischief  2009      2   17     2      30
# 63          Mischief            Mischief  2008      8   21     1      50
# 71          Mischief  Theft from Vehicle  2017      4   28     6      45
# 118         Mischief  Theft from Vehicle  2015      1   19     5      51
# ...              ...                 ...   ...    ...  ...   ...     ...
# 88230       Mischief  Theft from Vehicle  2005      5   16     5      58
# 88265       Mischief  Theft from Vehicle  2007      6   25     7      47
# 88413       Mischief  Theft from Vehicle  2013     10   12     1      30
# 88426       Mischief            Mischief  2013      8   23     1      40
# 88473       Mischief            Mischief  2013      4   27    19      54
#
#        DayOfWeek  WeekOfYear          X           Y   Latitude   Longitude
# 32             6           3  490470.88  5458197.99  49.276464 -123.131008
# 37             2           8  496297.61  5458207.06  49.276609 -123.050901
# 63             4          34  489905.08  5456038.01  49.257026 -123.138732
# 71             5          17  491792.73  5459252.20  49.285966 -123.112857
# 118            1           4  495339.83  5456209.14  49.258631 -123.064046
# ...          ...         ...        ...         ...        ...         ...
# 88230          1          20  491758.44  5459079.59  49.284413 -123.113325
# 88265          1          26  491789.20  5458959.71  49.283335 -123.112899
# 88413          6          41  494830.61  5456932.79  49.265136 -123.071054
# 88426          5          34  493177.29  5453039.25  49.230096 -123.093712
# 88473          6          17  498038.64  5453379.95  49.233196 -123.026942
#
# [3669 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Mischief'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 160         Mischief                        Other Theft  2008      8    5
# 162         Mischief  Break and Enter Residential/Other  2004      7   30
# 165         Mischief                 Theft from Vehicle  2012      6   24
# 448         Mischief                 Theft from Vehicle  2013     10    8
# 465         Mischief                           Mischief  2015      4   27
# ...              ...                                ...   ...    ...  ...
# 88060       Mischief                        Other Theft  2010      3    6
# 88086       Mischief  Break and Enter Residential/Other  2008      8   10
# 88141       Mischief  Break and Enter Residential/Other  2017      4   13
# 88172       Mischief                           Mischief  2003     12    5
# 88393       Mischief                        Other Theft  2011      8   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 160      10      55          2          32  493399.03  5452635.98  49.226471
# 162      17      56          5          31  498126.75  5459571.69  49.288892
# 165      20      45          7          25  492588.75  5453315.09  49.232571
# 448      18      50          2          41  493844.89  5454164.30  49.240224
# 465       3      56          1          18  487404.45  5455141.38  49.248914
# ...     ...     ...        ...         ...        ...         ...        ...
# 88060    12      45          6           9  495228.06  5453412.77  49.233476
# 88086     5      57          7          32  495604.91  5453347.97  49.232896
# 88141    22      51          4          15  487467.43  5455037.32  49.247979
# 88172    18      45          5          49  497949.85  5458807.78  49.282020
# 88393    16      52          6          32  493397.06  5452944.43  49.229246
#
#         Longitude
# 160   -123.090660
# 162   -123.025760
# 165   -123.101801
# 448   -123.084560
# 465   -123.173070
# ...           ...
# 88060 -123.065549
# 88086 -123.060371
# 88141 -123.172201
# 88172 -123.028189
# 88393 -123.090692
#
# [1178 rows x 13 columns]

# %%
display("Original Naive Bayes: Break and Enter Residential/Other", SKNB[SKNB['Predicted Type'] == "Break and Enter Residential/Other"])
display("Naive Bayes with Recursive Feature Elimination: Break and Enter Residential/Other", SKRFE[SKRFE['Predicted Type'] == "Break and Enter Residential/Other"])
# Out:
# 'Original Naive Bayes: Break and Enter Residential/Other'
#                           Predicted Type                        Actual Type  \
# 15     Break and Enter Residential/Other                           Mischief
# 16     Break and Enter Residential/Other                 Theft from Vehicle
# 21     Break and Enter Residential/Other  Break and Enter Residential/Other
# 31     Break and Enter Residential/Other                           Mischief
# 36     Break and Enter Residential/Other  Break and Enter Residential/Other
# ...                                  ...                                ...
# 88455  Break and Enter Residential/Other  Break and Enter Residential/Other
# 88470  Break and Enter Residential/Other                 Theft from Vehicle
# 88472  Break and Enter Residential/Other                           Mischief
# 88474  Break and Enter Residential/Other                        Other Theft
# 88497  Break and Enter Residential/Other                 Theft from Vehicle
#
#        YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 15     2007     10   11     1      41          4          41  490750.27
# 16     2005      8   15    16      30          1          33  490186.83
# 21     2006      1    2     1      30          1           1  494653.13
# 31     2005     11   19     4       0          6          46  485895.79
# 36     2015     12    5    18      30          6          49  497546.85
# ...     ...    ...  ...   ...     ...        ...         ...        ...
# 88455  2014      8   31    12      45          7          35  497955.56
# 88470  2004     11   28     5      32          7          48  489975.05
# 88472  2014      3   10    14       0          1          11  497995.76
# 88474  2009      1   28    20      31          3           5  489762.32
# 88497  2008      5   11     3      15          7          19  494995.46
#
#                 Y   Latitude   Longitude
# 15     5450638.13  49.208466 -123.126993
# 16     5450074.65  49.203389 -123.134714
# 21     5452495.27  49.225218 -123.073434
# 31     5453328.33  49.232572 -123.193736
# 36     5452720.38  49.227261 -123.033693
# ...           ...        ...         ...
# 88455  5450997.34  49.211764 -123.028071
# 88470  5450990.73  49.211625 -123.137645
# 88472  5453265.15  49.232163 -123.027530
# 88474  5450762.71  49.209571 -123.140560
# 88497  5451114.71  49.212802 -123.068715
#
# [6539 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Break and Enter Residential/Other'
#                           Predicted Type                        Actual Type  \
# 15     Break and Enter Residential/Other                           Mischief
# 16     Break and Enter Residential/Other                 Theft from Vehicle
# 36     Break and Enter Residential/Other  Break and Enter Residential/Other
# 50     Break and Enter Residential/Other                           Mischief
# 53     Break and Enter Residential/Other                           Mischief
# ...                                  ...                                ...
# 88470  Break and Enter Residential/Other                 Theft from Vehicle
# 88472  Break and Enter Residential/Other                           Mischief
# 88473  Break and Enter Residential/Other                           Mischief
# 88474  Break and Enter Residential/Other                        Other Theft
# 88497  Break and Enter Residential/Other                 Theft from Vehicle
#
#        YEAR  MONTH  DAY  HOUR  MINUTE  DayOfWeek  WeekOfYear          X  \
# 15     2007     10   11     1      41          4          41  490750.27
# 16     2005      8   15    16      30          1          33  490186.83
# 36     2015     12    5    18      30          6          49  497546.85
# 50     2014      5   27    18       0          2          22  497388.56
# 53     2003     12   19    18      50          5          51  489250.18
# ...     ...    ...  ...   ...     ...        ...         ...        ...
# 88470  2004     11   28     5      32          7          48  489975.05
# 88472  2014      3   10    14       0          1          11  497995.76
# 88473  2013      4   27    19      54          6          17  498038.64
# 88474  2009      1   28    20      31          3           5  489762.32
# 88497  2008      5   11     3      15          7          19  494995.46
#
#                 Y   Latitude   Longitude
# 15     5450638.13  49.208466 -123.126993
# 16     5450074.65  49.203389 -123.134714
# 36     5452720.38  49.227261 -123.033693
# 50     5451589.82  49.217091 -123.035860
# 53     5453366.65  49.232985 -123.147661
# ...           ...        ...         ...
# 88470  5450990.73  49.211625 -123.137645
# 88472  5453265.15  49.232163 -123.027530
# 88473  5453379.95  49.233196 -123.026942
# 88474  5450762.71  49.209571 -123.140560
# 88497  5451114.71  49.212802 -123.068715
#
# [6350 rows x 13 columns]

# %%
display("Original Naive Bayes: Other Theft", SKNB[SKNB['Predicted Type'] == "Other Theft"])
display("Naive Bayes with Recursive Feature Elimination: Other Theft", SKRFE[SKRFE['Predicted Type'] == "Other Theft"])
# Out:
# 'Original Naive Bayes: Other Theft'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 10       Other Theft                 Theft from Vehicle  2008      7   19
# 23       Other Theft                 Theft from Vehicle  2009     12   21
# 29       Other Theft                        Other Theft  2007      2   24
# 30       Other Theft                 Theft from Vehicle  2017      6   16
# 33       Other Theft                        Other Theft  2017      6   14
# ...              ...                                ...   ...    ...  ...
# 88487    Other Theft                        Other Theft  2007      1    9
# 88490    Other Theft                           Mischief  2012     11   23
# 88493    Other Theft  Break and Enter Residential/Other  2008      2   15
# 88505    Other Theft                           Mischief  2006     10    8
# 88515    Other Theft                           Mischief  2014      5   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 10       18      47          6          29  491833.57  5459286.88  49.286279
# 23       11      56          1          52  490955.33  5459482.91  49.288030
# 29       14      43          6           8  491827.08  5459079.55  49.284414
# 30       18      35          5          24  490951.41  5456220.14  49.258680
# 33       17      46          3          24  490240.33  5459772.54  49.290624
# ...     ...     ...        ...         ...        ...         ...        ...
# 88487    12      44          2           2  491394.12  5458844.26  49.282291
# 88490    14      39          5          47  493605.51  5455356.03  49.250941
# 88493    12      44          5           7  492627.03  5454817.01  49.246081
# 88505    14      45          7          40  496487.75  5458028.74  49.275006
# 88515    18      40          2          20  491593.15  5459475.93  49.287976
#
#         Longitude
# 10    -123.112296
# 23    -123.124377
# 29    -123.112381
# 30    -123.124357
# 33    -123.134216
# ...           ...
# 88487 -123.118329
# 88490 -123.087867
# 88493 -123.101303
# 88505 -123.048286
# 88515 -123.115606
#
# [12107 rows x 13 columns]
# 'Naive Bayes with Recursive Feature Elimination: Other Theft'
#       Predicted Type                        Actual Type  YEAR  MONTH  DAY  \
# 10       Other Theft                 Theft from Vehicle  2008      7   19
# 23       Other Theft                 Theft from Vehicle  2009     12   21
# 29       Other Theft                        Other Theft  2007      2   24
# 32       Other Theft                           Mischief  2015      1   17
# 33       Other Theft                        Other Theft  2017      6   14
# ...              ...                                ...   ...    ...  ...
# 88480    Other Theft                        Other Theft  2009      3   17
# 88487    Other Theft                        Other Theft  2007      1    9
# 88493    Other Theft  Break and Enter Residential/Other  2008      2   15
# 88505    Other Theft                           Mischief  2006     10    8
# 88515    Other Theft                           Mischief  2014      5   13
#
#        HOUR  MINUTE  DayOfWeek  WeekOfYear          X           Y   Latitude  \
# 10       18      47          6          29  491833.57  5459286.88  49.286279
# 23       11      56          1          52  490955.33  5459482.91  49.288030
# 29       14      43          6           8  491827.08  5459079.55  49.284414
# 32        1      53          6           3  490470.88  5458197.99  49.276464
# 33       17      46          3          24  490240.33  5459772.54  49.290624
# ...     ...     ...        ...         ...        ...         ...        ...
# 88480    14      39          2          12  491445.91  5458896.41  49.282761
# 88487    12      44          2           2  491394.12  5458844.26  49.282291
# 88493    12      44          5           7  492627.03  5454817.01  49.246081
# 88505    14      45          7          40  496487.75  5458028.74  49.275006
# 88515    18      40          2          20  491593.15  5459475.93  49.287976
#
#         Longitude
# 10    -123.112296
# 23    -123.124377
# 29    -123.112381
# 32    -123.131008
# 33    -123.134216
# ...           ...
# 88480 -123.117618
# 88487 -123.118329
# 88493 -123.101303
# 88505 -123.048286
# 88515 -123.115606
#
# [10657 rows x 13 columns]
